# %%
from run import *
'''
Run the line below
'''
dispatch('JSON/simplesubgraph.json')
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-1-90eeddd85995> in <module>()
# ----> 1 from run import *
#       2 dispatch('JSON/simplesubgraph.json')
#
# ImportError: No module named run
